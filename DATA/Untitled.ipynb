# %%
import pandas as pd
df = pd.read_excel('서울특별시 가로쓰레기통 현황_202106.xlsx',header=1)
df
# Out:
#       Unnamed: 0    연번 자치구명   도로명 세부 위치(상세 주소)                설치 지점  \
# 0            NaN     1  종로구   사직로    경복궁역 4번출구              지하철역 입구
# 1            NaN     2  종로구   사직로    경복궁역 4번출구              지하철역 입구
# 2            NaN     3  종로구  자하문로      자하문로 28              도로(가로)변
# 3            NaN     4  종로구  자하문로      자하문로 28              도로(가로)변
# 4            NaN     5  종로구  자하문로      자하문로 44              도로(가로)변
# ...          ...   ...  ...   ...          ...                  ...
# 5370         NaN  5371  도봉구   해등로     해등로3길 41          삼환빌라 앞 횡단보도
# 5371         NaN  5372  도봉구   해등로     해등로 103         창원초등학교 앞 횡단보도
# 5372         NaN  5373  도봉구  도봉산길      도봉산길 27      도봉고등학교 건너편 횡단보도
# 5373         NaN  5374  도봉구   도봉로   도봉동 620-23  신도봉사거리 도봉중학교방향 횡단보도
# 5374         NaN  5375  도봉구   해등로       해등로 32    창1동 서울가든아파트 버스정류장
#
#      수거 쓰레기 종류(일반 쓰레기 / 재활용 쓰레기)
# 0                          일반쓰레기
# 1                            재활용
# 2                          일반쓰레기
# ...
