# %%
#버스정류장, 역, 공원, 전체인구, 도서관 
import pandas as pd
import googlemaps
googlemaps_key = 'AIzaSyCfWOzKIjZ2kSQ4qK0_S0VuggIlyOfLUYI'
gmaps = googlemaps.Client(key=googlemaps_key)

# %%
bus_data = pd.read_csv('../DATA/서울특별시 버스정류소 위치정보.csv', encoding='cp949')
bus_data = pd.DataFrame(bus_data)
df = pd.read_excel('../DATA/서울시 고령층 데이터 2021.xls',header = 1)
df = pd.DataFrame(df)
df = df[df['자치구']=='강서구']
df = df[['동','전체인구']]
df = df.drop([df.index[0]])
hjd = list(df['동'])
bus_data.head()
# Out:
#    정류소번호           정류소명         X좌표        Y좌표
# 0   1001        종로2가사거리  126.987786  37.569764
# 1   1002    창경궁.서울대학교병원  126.996520  37.579179
# 2   1003      명륜3가.성대입구  126.998290  37.582709
# 3   1004       종로2가.삼일교  126.987507  37.568582
# 4   1005  혜화동로터리.여운형활동터  127.001694  37.586230

# %%
ans = []
for lt in range(len(bus_data)):
    x = bus_data['Y좌표'][lt]
    y = bus_data['X좌표'][lt]
    try : 
        r = gmaps.reverse_geocode((x,y), language='ko')
        if lt % 100 == 0 :
            print(lt,'/',len(bus_data), '진행')
        for i in r :
            sn = i.get('address_components')
            for k in sn :
                j = k.get('short_name')
                ck = []
                for n in hjd :
                    if n == j:
                        ans.append(n)
    except :
        print('pass')
# Out:
# 0 / 10921 진행
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# 100 / 10921 진행
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# ...

# %%
x = bus_data['Y좌표'][0]
y = bus_data['X좌표'][0]
print(gmaps.reverse_geocode((x,y), language='ko'))
# Out:
# [{'address_components': [{'long_name': '종로2가사거리', 'short_name': '종로2가사거리', 'types': ['establishment', 'point_of_interest', 'transit_station']}, {'long_name': '서울특별시', 'short_name': '서울특별시', 'types': ['administrative_area_level_1', 'political']}, {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']}, {'long_name': '110-122', 'short_name': '110-122', 'types': ['postal_code']}], 'formatted_address': '대한민국 서울특별시 종로2가사거리', 'geometry': {'location': {'lat': 37.569681, 'lng': 126.987763}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 37.57102998029149, 'lng': 126.9891119802915}, 'southwest': {'lat': 37.5683320197085, 'lng': 126.9864140197085}}}, 'place_id': 'ChIJmQR9SuaifDURbUwnYWA9qUA', 'plus_code': {'compound_code': 'HX9Q+V4 대한민국 서울특별시', 'global_code': '8Q98HX9Q+V4'}, 'types': ['establishment', 'point_of_interest', 'transit_station']}, {'address_components': [{'long_name': '８４−１１', 'short_name': '８４−１１', 'types': ['premise']}, {'long_name': '
# ...

# %%
nu = 0
for i in hjd_set :
    a = 0
    for k in ans :
        if k == i :
            a+=1
    nu.append(a)
