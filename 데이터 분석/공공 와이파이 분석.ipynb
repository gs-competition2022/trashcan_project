# %%
import pandas as pd
import folium
df = pd.read_excel("../DATA/서울특별시강서구공공와이파이서비스위치정보.xls",header=1)
df = pd.DataFrame(df)

df1 = pd.read_excel('../DATA/서울시 고령층 데이터 2021.xls',header = 1)
df1 = pd.DataFrame(df1)
df1 = df1[df1['자치구']=='강서구']
df1 = df1['동']
df1 = df1.drop([df1.index[0]])
l = list(df['x_swifi_inout_door'])
oi = 0
nae = 0
for i in l :
    if i == '실외':
        oi += 1
    elif i == '실내':
        nae += 1
print(oi, nae)

#실외가 실내보다 많음
# Out:
# 949 406

# %%
df2 = pd.read_excel("../DATA/서울특별시강서구공공와이파이서비스위치정보.xls",header=1)
df2 = pd.DataFrame(df2)
df2
# Out:
#      x_swifi_mgr_no x_swifi_wrdofc x_swifi_main_nm           x_swifi_adres1  \
# 0          BS100171            강서구        KBS스포츠월드               등촌동 665-13
# 1          BS100172            강서구        KBS스포츠월드               화곡동 1136-1
# 2          BS100173            강서구          KT가양지사                  강서로 442
# 3          BS100174            강서구          KT가양지사                가양동 1070답
# 4          BS100175            강서구      가로공원.나누리병원              가로공원로 184-2
# ...             ...            ...             ...                      ...
# 1350       WF201189            강서구         강서청소년쉼터       강서구 초록마을로10길5 201호
# 1351       WF201190            강서구         강서청소년쉼터       강서구 초록마을로10길5 201호
# 1352       WF201191            강서구        어울림청소년쉼터  강서구 공항대로48길76 예루뜨빌 303호
# 1353       WF201192            강서구        어울림청소년쉼터  강서구 공항대로48길76 예루뜨빌 303호
# 1354       WF201193            강서구       큰미래지역아동센터     강서구 방화대로 23길 49-5 1층
#
# ...

# %%
d = set(list(df1))

# %%
import googlemaps

googlemaps_key = 'AIzaSyCfWOzKIjZ2kSQ4qK0_S0VuggIlyOfLUYI'

gmaps = googlemaps.Client(key=googlemaps_key)

# %%
r = gmaps.reverse_geocode((37.542007,126.849230),language='ko')
for i in r :
    m = i.get('address_components')[0].get('short_name')
    print(m)
# Out:
# ５
# 거성빌라
# GRRX+RM
# 초록마을로
# 화곡본동
# 157-019
# 화곡동
# 강서구
# 서울특별시
# 서울특별시
# KR

# %%
import pandas as pd
import requests 
import sys
import json
import datetime 
def json_request(url='', encoding='utf-8', success=None, error=lambda e: print('%s : %s' % (e, datetime.now()), file=sys.stderr)):
    headers = {'Authorization': 'KakaoAK {}'.format(APP_KEY)}
    resp = requests.get(url, headers=headers)
    # print('%s : success for request [%s]' % (datetime.now(), url))
    return resp.text


def reverse_geocode(longitude, latitude):
    # 파라미터 최적화하여 url 생성
    url = '%s?x=%s&y=%s' %(URL, longitude, latitude)
    # json request
    try:
        # print('try')
        json_req = json_request(url=url)
        json_data = json.loads(json_req)
        json_doc = json_data.get('documents')[0]
        json_name = json_doc.get('address_name')
        json_code = json_doc.get('code')
    except:
        # print('nan')
        json_name = 'NaN'
        json_code = 'NaN'
    return json_name, json_code

 
def get_address(x,y):
    address = []        
    json_name, json_code = reverse_geocode(x, y) 
    address.append(json_name)
    return address # 전처리 함수에서 주소 리스트 받아서 데이터프레임에 추가


def get_code(x,y):
    code = []        
    json_name, json_code = reverse_geocode(x, y) 
    code.append(json_code)
    return code # 전처리 함수에서 행정구역코드 리스트 받아서 데이터프레임에 추가

APP_KEY = 'af4b7144aab34ccc2d9995ba730ab6c5' 
URL = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json'

df = df[['x_swifi_mgr_no', 'lat', 'lnt', 'x_swifi_']] # 기관ID, 병원경도, 병원위도 열만 추출 (도로명주소는 일부러 날림)


for i in range(len(df)): 
    x_crd = float(df.loc[i, ['lat']])
    y_crd = float(df.loc[i, ['lnt']])
    address = get_address(x_crd, y_crd)
    code = get_code(x_crd, y_crd)
    df.loc[i, ['ADDRESS']] = address
    df.loc[i, ['CODE']] = code
    
    if i%100 == 0:
        print('{} 번째 경위도 좌표계에 대한 정보 불러오는 중...'.format(i))
# Out:
# 0 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 100 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 200 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 300 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 400 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 500 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 600 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 700 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 800 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 900 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1000 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1100 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1200 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1300 번째 경위도 좌표계에 대한 정보 불러오는 중...

# %%
df
# Out:
#      x_swifi_mgr_no         lat        lnt        ADDRESS        CODE
# 0          BS100171  126.850464  37.556602  서울특별시 강서구 등촌동  1150010200
# 1          BS100172  126.849236  37.556910  서울특별시 강서구 화곡동  1150010300
# 2          BS100173  126.840440  37.564820  서울특별시 강서구 등촌동  1150010200
# 3          BS100174  126.840096  37.564888  서울특별시 강서구 마곡동  1150010500
# 4          BS100175  126.836450  37.536827  서울특별시 강서구 화곡동  1150010300
# ...             ...         ...        ...            ...         ...
# 1350       WF201189  126.849230  37.542007  서울특별시 강서구 화곡동  1150010300
# 1351       WF201190  126.849230  37.542007  서울특별시 강서구 화곡동  1150010300
# 1352       WF201191  126.853584  37.551506  서울특별시 강서구 화곡동  1150010300
# 1353       WF201192  126.853584  37.551506  서울특별시 강서구 화곡동  1150010300
# 1354       WF201193  126.813720  37.564040  서울특별시 강서구 공항동  1150010800
#
# [1355 rows x 5 columns]

# %%
import folium
data_map = df
m = folium.Map([37.55459659834, 126.83722951069], zoom_start=12)

for i in data_map.index:
    sl = data_map.loc[i,'lnt']
    st = data_map.loc[i,'lat']
    
    tooltip = 'wifi'
    folium.Marker([sl, st],tooltip=tooltip).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
print(set(list(df['ADDRESS'])))
# Out:
# {'서울특별시 양천구 목동', '서울특별시 강서구 내발산동', '서울특별시 강서구 방화동', '서울특별시 강서구 등촌동', '서울특별시 강서구 과해동', '서울특별시 강서구 가양동', '서울특별시 강서구 염창동', '서울특별시 양천구 신월동', '서울특별시 강서구 공항동', '서울특별시 강서구 화곡동', '서울특별시 강서구 개화동', '서울특별시 강서구 외발산동', '서울특별시 강서구 마곡동'}
