# %%
import pandas as pd
import folium
df = pd.read_excel("../DATA/서울특별시강서구공공와이파이서비스위치정보.xls",header=1)
df = pd.DataFrame(df)

df1 = pd.read_excel('../DATA/서울시 고령층 데이터 2021.xls',header = 1)
df1 = pd.DataFrame(df1)
df1 = df1[df1['자치구']=='강서구']
df1 = df1['동']
df1 = df1.drop([df1.index[0]])
l = list(df['x_swifi_inout_door'])
oi = 0
nae = 0
for i in l :
    if i == '실외':
        oi += 1
    elif i == '실내':
        nae += 1
print(oi, nae)

#실외가 실내보다 많음

for i in list(df[''])
# Out:
# 949 406
# 258     염창동
# 259    등촌1동
# 260    등촌2동
# 261    등촌3동
# 262    화곡본동
# 263    화곡2동
# 264    화곡3동
# 265    화곡4동
# 266    화곡6동
# 267    화곡8동
# 268    가양1동
# 269    가양2동
# 270    가양3동
# 271    발산1동
# 272     공항동
# 273    방화1동
# 274    방화2동
# 275    방화3동
# 276    화곡1동
# 277    우장산동
# Name: 동, dtype: object

# %%
import pandas as pd
import requests 
import sys
import json
import datetime 
def json_request(url='', encoding='utf-8', success=None, error=lambda e: print('%s : %s' % (e, datetime.now()), file=sys.stderr)):
    headers = {'Authorization': 'KakaoAK {}'.format(APP_KEY)}
    resp = requests.get(url, headers=headers)
    # print('%s : success for request [%s]' % (datetime.now(), url))
    return resp.text


def reverse_geocode(longitude, latitude):
    # 파라미터 최적화하여 url 생성
    url = '%s?x=%s&y=%s' %(URL, longitude, latitude)
    # json request
    try:
        # print('try')
        json_req = json_request(url=url)
        json_data = json.loads(json_req)
        json_doc = json_data.get('documents')[0]
        json_name = json_doc.get('address_name')
        json_code = json_doc.get('code')
    except:
        # print('nan')
        json_name = 'NaN'
        json_code = 'NaN'
    return json_name, json_code

 
def get_address(x,y):
    address = []        
    json_name, json_code = reverse_geocode(x, y) 
    address.append(json_name)
    return address # 전처리 함수에서 주소 리스트 받아서 데이터프레임에 추가


def get_code(x,y):
    code = []        
    json_name, json_code = reverse_geocode(x, y) 
    code.append(json_code)
    return code # 전처리 함수에서 행정구역코드 리스트 받아서 데이터프레임에 추가

APP_KEY = 'af4b7144aab34ccc2d9995ba730ab6c5' 
URL = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json'

df = df[['x_swifi_mgr_no', 'lat', 'lnt']] # 기관ID, 병원경도, 병원위도 열만 추출 (도로명주소는 일부러 날림)


for i in range(len(df)): 
    x_crd = float(df.loc[i, ['lat']])
    y_crd = float(df.loc[i, ['lnt']])
    address = get_address(x_crd, y_crd)
    code = get_code(x_crd, y_crd)
    df.loc[i, ['ADDRESS']] = address
    df.loc[i, ['CODE']] = code
    
    if i%100 == 0:
        print('{} 번째 경위도 좌표계에 대한 정보 불러오는 중...'.format(i))
# Out:
# C:\Users\habru\Anaconda3\lib\site-packages\pandas\core\indexing.py:659: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[k] = np.nan
# C:\Users\habru\Anaconda3\lib\site-packages\pandas\core\indexing.py:1760: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# 0 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 100 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 200 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 300 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 400 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 500 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 600 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 700 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 800 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 900 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1000 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1100 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1200 번째 경위도 좌표계에 대한 정보 불러오는 중...
# 1300 번째 경위도 좌표계에 대한 정보 불러오는 중...

# %%
df
# Out:
#      x_swifi_mgr_no         lat        lnt        ADDRESS        CODE
# 0          BS100171  126.850464  37.556602  서울특별시 강서구 등촌동  1150010200
# 1          BS100172  126.849236  37.556910  서울특별시 강서구 화곡동  1150010300
# 2          BS100173  126.840440  37.564820  서울특별시 강서구 등촌동  1150010200
# 3          BS100174  126.840096  37.564888  서울특별시 강서구 마곡동  1150010500
# 4          BS100175  126.836450  37.536827  서울특별시 강서구 화곡동  1150010300
# ...             ...         ...        ...            ...         ...
# 1350       WF201189  126.849230  37.542007  서울특별시 강서구 화곡동  1150010300
# 1351       WF201190  126.849230  37.542007  서울특별시 강서구 화곡동  1150010300
# 1352       WF201191  126.853584  37.551506  서울특별시 강서구 화곡동  1150010300
# 1353       WF201192  126.853584  37.551506  서울특별시 강서구 화곡동  1150010300
# 1354       WF201193  126.813720  37.564040  서울특별시 강서구 공항동  1150010800
#
# [1355 rows x 5 columns]

# %%
d = pd.read_excel("../DATA/서울특별시강서구공공와이파이서비스위치정보.xls",header=1)
d = pd.DataFrame(d)
d.head()
m = pd.concat([df,d['x_swifi_adres1']],axis=1)
m1 = pd.concat([m, d['x_swifi_inout_door']],axis=1)
li = list(m1['x_swifi_adres1'])
for i in li :
    if '로' in str(i) :
        print(i)
# new_li = []
# for i in li :
#     i = str(i)
#     if '강서구' in i :
#         i = '서울특별시 ' + i
#     else :
#         i = '서울특별시 강서구 ' +i 
#     new_li.append(i)
# for i in new_li :
#     print(i)
# Out:
# 강서로 442
# 가로공원로 184-2
# 가로공원로 181
# 허준로 47
# 양천로 507
# 허준로 23
# 양천로 564
# 남부순환로 29
# 금낭화로 80
# 허준로 121
# 강서로56나길 110
# 공항대로
# 공항대로
# 강서로 490
# 공항대로
# 공항대로
# 강서로 266
# 공항대로
# 공항대로
# 등촌2 513-14 아이파크아파트.백석중학교.실로암안과(16-174)
# 가로공원로 219 화원중학교(16-202)
# 마곡동 727-1113 마곡역교차로(16-387)
# 염창동 53-1  지하 에어로빅실
# 양천로 721
# 양천로699
# 양천로 605
# 양천로 583
# 화곡로 302
# 화곡로68길 10
# 화곡로68길 47
# 화곡로66길 83
# 공항대로55길 50
# 공항대로59길 64
# 공항대로59길 35
# 공항대로57길 31
# 공항대로 489
# 공항대로 491
# 공항대로55길 2
# 공항대로 431(신호단속 카메라 옆 가로등)
# 공항대로 431(LG전자 베스트샵 주차장 입구 가로등)
# 공항대로 425
# 등촌로 217(16173 버스정류장 옆 가로등)
# 화곡로 384
# 공항대로58가길 20
# 공항대로58나길 10-50
# 공항대로58가길 39
# 공항대로58가길 72-3
# 공항대로58나길 55
# 등촌로51길 116
# 공항대로 58길 32
# 등촌로 53길 천우네오젠
# 등촌로51길 45
# 등촌로51나길 13
# 등촌로 51가길 15
# 등촌로39길 30
# 등촌로39길 63
# 등촌로39마길 24
# 등촌로39가길 27
# 등촌로 229-1
# 등촌로35길 115
# 등촌로35길 158
# 곰달래로59길 67
# 등촌로51길14
# 등촌로 39바길 26
# 등촌로 51나길 29
# 등촌로 143
# 강서로74길 21
# 강서로 460
# 강서로68길35
# 강서로 56가길 53
# 강서로68길 58
# 양천로 434
# 공항대로 41길 43
# 공항대로39길 39
# 공항대로 321
# 강서로56길 44
# 화곡로63가길 26
# 화곡로61길 85
# 화곡로63길 65
# 화곡로61길26
# 화곡로375
# 화곡로69길 9
# 양천로 492
# 등촌동 698 로얄프라자 앞 CCTV
# 공항대로 379
# 공항대로 383
# 공항대로 375
# 공항대로 337
# 공항대로 323
# 공항대로 281
# 까치산로 101
# 까치산로 93
# 까치산로 83
# 까치산로 75
# 까치산로 65
# 까치산로 55
# 까치산로 45
# 까치산로 37
# 까치산로 29
# 까치산로 19
# 까치산로 11
# 까치산로 4
# 강서로 63
# 강서로 55
# 강서로 47
# 강서로 43-17
# 가로공원로76길 75
# 가로공원로76길 100
# 강서로17길 101
# 강서로5나길 94
# 곰달래로 109
# 곰달래로 119
# 곰달래로 125
# 가로공원로 219-1
# 가로공원로 183
# 가로공원로 187
# 화곡동 425-4(지상3층 프로그램실)
# 화곡2동 875-8 CCTV(16183 버스정류장 옆 가로등)
# 곰달래로 211
# 곰달래로 219
# 강서로45길 49 CU편의점
# 강서로 215-1
# 강서로 207
# 강서로 199
# 강서로 187
# 화곡로 161
# 화곡로25길 2
# 화곡로 143
# 화곡로13길 90-53
# 강서로 239
# 화곡로 119
# 화곡로 113
# 등촌로 59
# 등촌로 49
# 등촌로 31
# 곰달래로 271
# 곰달래로 261
# 곰달래로 257
# 곰달래로 245
# 곰달래로 235
# 화곡6동 980-16  6층 도로과
# 우장산로 109
# 우장산로 121
# 까치산로 182
# 까치산로 178-2
# 까치산로 168
# 까치산로 160
# 까치산로 144
# 까치산로 138
# 화곡8동 155-1  안골경로당 옆
# 곰달래로 141
# 곰달래로 149
# 곰달래로 157
# 우장산동 1159 CCTV(우장산아이파크 정문, 16352 버스정류장 옆 가로등)
# 우장산동 702-22 CCTV(횡단보도 가로등)
# 우장산로 11-1
# 우장산로 19-1
# 우장산로 31
# 우장산로8길 4
# 화곡로43길6
# 화곡로43길 12
# 화곡로43길 34
# 화곡로 237
# 화곡로 227
# 화곡로 217
# 화곡로 207
# 화곡로 197
# 화곡로 187
# 화곡로 179(화곡역 1,2번출구 사이 가로등)
# 양천로47길118
# 양천로47길 94
# 양천로47길 54
# 양천로49길 77
# 양천로49길 44
# 강서로 511
# 강서로 521
# 강서로532
# 허준로 12
# 허준로 55-20
# 양천로 390
# 양천로47가길 40
# 양천로47가길 25-18
# 양천로 401
# 가양2동 1471  공원 중간 쉼터(가로등)
# 허준로 65
# 허준로 121
# 양천로57길 13
# 허준로176
# 허준로186
# 양천로59길 가양초등학교
# 허준로221-40
# 허준로 209
# 허준로 217
# 허준로 230
# 양천로 559
# 강서로 329
# 강서로 317-3
# 강서로 299
# 강서로45길 87
# 강서로45길 104
# 강서로45길 144
# 강서로 279-22
# 강서로45라길 35
# 강서로47라길 64
# 강서로47다길 36
# 강서로47라길 37
# 강서로47라길 27
# 강서로47라길 10
# 강서로47마길 10
# 강서로47바길 40
# 강서로47바길 21
# 강서로 353
# 강서로 349
# 강서로 357
# 강서로 271
# 공항동 60-28  1층 프로그램실
# 송정로 71
# 송정로 63-1
# 송정로 53
# 송정로 47
# 송정로 39
# 송정로 29-1
# 송정로 21
# 송정로 9
# 남부순환로7길 39
# 공항대로2가길 19
# 남부순환로5길 31
# 남부순환로7길 30
# 공항대로4길 11
# 공항대로8길 13
# 공항대로8길 33-7
# 공항대로8길 56
# 공항대로8가길 12-8
# 공항대로8가길 36
# 방화대로7다길 13
# 남부순환로11가길 28
# 방화대로5다길 22-11
# 남부순환로11길 48
# 방화대로8길 28
# 방화대로6가길 5
# 방화대로6바길 5-14
# 방화대로6가길2
# 공항대로3길 18(송정역 1번 출구 앞 가로등)
# 공항대로3길 18(미니스톱 쪽 횡단보도 뎦 가로등)
# 곰달래로25길 45
# 3층 다용도실
# 방화동로 1
# 방화동로 6
# 방화동로 16
# 방화동로 24
# 공항대로3길 18
# 공항대로 3길 11
# 공항대로7길 11
# 공항대로7길 27
# 공항대로7나길 31
# 방화대로21길 69
# 방화대로21길 45
# 방화대로21길 26
# 방화대로23길 27
# 공항대로53
# 초원로16길 3-9
# 방화동로 52
# 방화동로 44
# 양천로18길 21
# 양천로 20가길 4
# 양천로24가길 31
# 양천로24길15
# 방화동로 105
# 방화동로14길 37
# 양천로24길 113
# 초원로 66
# 방화동로12길 9
# 방화동로10길 17
# 방화대로25길 13
# 방화대로21다길 3
# 방화대로21길 70
# 양천로24가길9
# 방화대로34길 113
# 방화동로 65
# 방화동로 85
# 양천로16길 8
# 양천로14길118
# 초원로 12
# 개화동로 495
# 금낭화로 17
# 금낭화로 12
# 방화3동 855  농구장 옆 가로등
# 양천로 13 한국공항 정문
# 양천로3길 26
# 양천로7길11-4
# 양천로 11길 14
# 금낭화로 16길 14
# 방화대로45길 47
# 방화대로47길 43
# 금낭화로128
# 금낭화로136
# 금낭화로 146
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 서울 강서구 마곡동로 161
# 강서구 양천로27길 279-23 강서안내센터
# 강서구 양천로27길 279-23 강서안내센터
# 강서구 강서로 54
# 강서구 강서로5길 64
# 강서구 방화동로 126
# 강서구 방화동로 126
# 강서구 방화동로16길 19
# 강서구 월정로30길 60
# 강서구 월정로30길 82
# 강서구 강서로80길 117
# 강서구 강서로45길 91-44
# 강서구 강서로62길 35
# 강서구 방화동로 41
# 강서구 까치산로 145
# 강서구 양천로14길 86
# 강서구 화곡로43가길 33
# 강서구 금낭화로 136
# 강서구초록마을로14길44
# 강서구초록마을로14길44
# 강서구초록마을로14길44
# 강서구가로공원로76길28
# 강서구가로공원로76길28
# 강서구가로공원로76길28
# 강서구월정로30길96
# 강서구월정로30길96
# 강서구월정로30길96
# 강서구초록마을로15길12
# 강서구초록마을로15길12
# 강서구초록마을로15길12
# 강서구초록마을로15길12
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 강서로 68길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 양천로 57길 36
# 강서구 허준로 209
# 강서구 허준로 209
# 강서구 허준로 209
# 강서구 허준로 209
# 강서구 허준로 209
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 금낭화로 23길 25
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 개화동로 21길 4
# 강서구 까치산로136(화곡동)
# 강서구 까치산로 134,3층
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 허준로 95-9
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 금낭화로 26가길 120
# 강서구 까치산로4길41
# 강서구 강서로 34길 36, B1층
# 강서구 송정로1길19, 베이스 빌딩2층
# 강서구 강서로56길50 주양빌딩2층
# 강서구 금낭화로 26가길 130
# 강서구 금낭화로 26가길 130
# 강서구우장산로117
# 강서구우장산로117
# 강서구 양천로27길 279-23 강서안내센터
# 강서구 양천로57길 37
# 강서구 양천로57길 37
# 강서구 양천로57길 37
# 강서구 양천로57길 37
# 강서구 곰달래로 180
# 강서구 곰달래로 180
# 강서구 양천로 17길 26-2. 1층
# 강서구 공항대로65길 21, 상가1층
# 강서구 강서로 56길 96, 3층
# 강서구 화곡6동960-22,(까치산로22길 38)
# 강서구 화곡6동960-22,(까치산로22길 38)
# 강서구 화곡6동960-22,(까치산로22길 38)
# 강서구 화곡6동960-22,(까치산로22길 38)
# 강서구 금낭화로26가길 130
# 강서구 까치산로18나길 36 1층
# 강서구 공항대로501
# 강서구 공항대로501
# 강서구 공항대로501
# 강서구 공항대로501
# 강서구 까치산로 160-5(1,2층)
# 공항대로41길34 등촌동 700, 플러스존 203호
# 초록마을로15길 12
# 방화동로 115, 3층
# 방화동로 115, 3층
# 양천로132
# 양천로132
# 수명로68-23
# 수명로68-23
# 공항대로39길 59
# 공항대로 315
# 공항대로 315
# 화곡로 58길 30-7
# 강서구 강서로45길 174, 4층
# 강서구 강서로45길 174, 4층
# 공항대로2가길 5
# 공항대로2가길 5
# 공항대로2가길 5
# 공항대로2가길 5
# 강서구 강서로5길 50, 2층 (화곡동)
# 강서로56가길 166
# 강서로56가길 166
# 강서로56가길 166
# 강서로56가길 166
# 강서로56가길 166
# 강서구 초록마을로10길5 201호
# 강서구 초록마을로10길5 201호
# 강서구 공항대로48길76 예루뜨빌 303호
# 강서구 공항대로48길76 예루뜨빌 303호
# 강서구 방화대로 23길 49-5 1층
