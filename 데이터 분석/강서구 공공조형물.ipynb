# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\jiyeon\\Desktop\\백지연\\공모전\\projectGS2022\\trashcan_project\\DATA\\서울특별시 강서구_공공조형물 현황_20220223.csv', encoding='CP949')
data
# Out:
#     연번   종  류                  명  칭                  위  치       상세위치  \
# 0    1  상징조형물              새마을 지도자탑   서울특별시 강서구 화곡동 산60-1    우장 근린공원
# 1    2  상징조형물               구암 허준동상    서울특별시 강서구 가양동 1471    구암 근린공원
# 2    3  상징조형물           누가 바람을 보았는가  서울특별시 강서구 등촌동 630-13    매화 근린공원
# 3    4  조형시설물            황금자 여사 부조상     서울특별시 강서구 화곡로 302  강서구청 본관1층
# 4    5  상징조형물          또 다른 우주를 찾아서     서울특별시 강서구 화곡로 302   강서구청 본관앞
# 5    6  상징조형물               허준을 만나다  서울특별시 강서구 가양동 1476-2     허준테마거리
# 6    7  상징조형물             동의보감 집필의길  서울특별시 강서구 가양동 1469-3     허준테마거리
# 7    8  상징조형물        동양의학의 집대성 동의보감  서울특별시 강서구 가양동 1469-2     허준테마거리
# 8    9  상징조형물            허준 테마거리 기둥  서울특별시 강서구 가양동 1477-2     허준테마거리
# 9   10  상징조형물     의성 허준과 동의보감을 만나는길  서울특별시 강서구 가양동 1477-1     허준테마거리
# 10  11  상징조형물                 허준이야기  서울특별시 강서구 가양동 1477-2     허준테마거리
# 11  12  상징조형물        허준이 들려주는 건강이야기  서울특별시 강서구 가양동 1476-2     허준테마거리
# 12  13  상징조형물           동의보감 집필 이야기  서울특별시 강서구 가양동 1476-2     허준테마거리
# ...

# %%
# 지번주소와 도로명주소 구분

address = []

for i in data['위  치']:
    a = i.split(" ")
    address.append(a[2])
    
address
# Out:
# ['화곡동',
#  '가양동',
#  '등촌동',
#  '화곡로',
#  '화곡로',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동',
#  '가양동']

# %%
# 도로명주소 -> 지번주소로 변환

# 도로명주소 : 서울특별시 강서구 화곡로 302
# 지번주소 : 서울특별시 강서구 화곡동 980-16

data.at[3, '위  치'] = '서울특별시 강서구 화곡동 980-16'
data.at[4, '위  치'] = '서울특별시 강서구 화곡동 980-16'
data
# Out:
#     연번   종  류                  명  칭                  위  치       상세위치  \
# 0    1  상징조형물              새마을 지도자탑   서울특별시 강서구 화곡동 산60-1    우장 근린공원
# 1    2  상징조형물               구암 허준동상    서울특별시 강서구 가양동 1471    구암 근린공원
# 2    3  상징조형물           누가 바람을 보았는가  서울특별시 강서구 등촌동 630-13    매화 근린공원
# 3    4  조형시설물            황금자 여사 부조상  서울특별시 강서구 화곡동 980-16  강서구청 본관1층
# 4    5  상징조형물          또 다른 우주를 찾아서  서울특별시 강서구 화곡동 980-16   강서구청 본관앞
# 5    6  상징조형물               허준을 만나다  서울특별시 강서구 가양동 1476-2     허준테마거리
# 6    7  상징조형물             동의보감 집필의길  서울특별시 강서구 가양동 1469-3     허준테마거리
# 7    8  상징조형물        동양의학의 집대성 동의보감  서울특별시 강서구 가양동 1469-2     허준테마거리
# 8    9  상징조형물            허준 테마거리 기둥  서울특별시 강서구 가양동 1477-2     허준테마거리
# 9   10  상징조형물     의성 허준과 동의보감을 만나는길  서울특별시 강서구 가양동 1477-1     허준테마거리
# 10  11  상징조형물                 허준이야기  서울특별시 강서구 가양동 1477-2     허준테마거리
# 11  12  상징조형물        허준이 들려주는 건강이야기  서울특별시 강서구 가양동 1476-2     허준테마거리
# 12  13  상징조형물           동의보감 집필 이야기  서울특별시 강서구 가양동 1476-2     허준테마거리
# ...

# %%
import googlemaps

my_key = "AIzaSyCfWOzKIjZ2kSQ4qK0_S0VuggIlyOfLUYI"
maps = googlemaps.Client(key=my_key)
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
places = ["강남", "황상동", "해운대해수욕장"]

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d512f13d0946> in <module>
# ----> 1 import googlemaps
#       2
#       3 my_key = "AIzaSyCfWOzKIjZ2kSQ4qK0_S0VuggIlyOfLUYI"
#       4 maps = googlemaps.Client(key=my_key)
#       5 lat = []  #위도
#
# ModuleNotFoundError: No module named 'googlemaps'

# %%
import googlemaps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4cc1617e5f71> in <module>
# ----> 1 import googlemaps
#
# ModuleNotFoundError: No module named 'googlemaps'
